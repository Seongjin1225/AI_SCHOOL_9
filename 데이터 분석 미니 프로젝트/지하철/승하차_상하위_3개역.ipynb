# %% [markdown]
# <a href="https://colab.research.google.com/github/Seongjin1225/AI_SCHOOL_9/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EB%AF%B8%EB%8B%88%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/%EC%A7%80%ED%95%98%EC%B2%A0/%EC%8A%B9%ED%95%98%EC%B0%A8_%EC%83%81%ED%95%98%EC%9C%84_3%EA%B0%9C%EC%97%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 라이브러리 호출
import pandas as pd
import folium

# 데이터 불러오기 및 데이터 확인
data = pd.read_csv('/content/drive/MyDrive/AI스쿨 파일/seoul-metro-2021.logs.csv')
info = pd.read_csv('/content/drive/MyDrive/AI스쿨 파일/seoul-metro-station-info.csv')
data.head()
info.head()

# 필요한 컬럼만 추출하기
info = info[['station.code', 'station.name_full', 'geo.latitude','geo.longitude']]
info.head()

# 역 정보 기준으로 그룹화
data_sum = data.groupby('station_code').sum(numeric_only=False)  # 숫자형 데이터 타입 아닌거 있는 경우는 numeric_only=False 해줘야함
data_sum

# 데이터 합치기 위해 info의 인덱스 재설정
info = info.set_index('station.code')

# join 사용해 두 데이터 합치기
joined_data = data_sum.join(info)
joined_data.head()

# 2021년 1월 데이터만 추출
data_jan = data[(pd.to_datetime(data.timestamp).dt.year == 2021) & (pd.to_datetime(data.timestamp).dt.month == 1)]
jan_group = data_jan.groupby('station_code').sum(numeric_only=False)
jan_join = jan_group.join(info)

# 승차인원 상하위 3개 데이터
top_in = jan_join.sort_values(by='people_in')[-3:]
top_in
low_in = jan_join.sort_values(by='people_in')[:3]
low_in

# 하차인원 상하위 3개 데이터
top_out = jan_join.sort_values(by='people_out')[-3:]
top_out
low_out = jan_join.sort_values(by='people_out')[:3]
low_out
# Out:
#                                                       timestamp  people_in  \
# station_code
# 321           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...          0
# 2649          2021-01-07T05:00:00.000+09:002021-01-07T06:00:...          0
# 2615          2021-01-02T05:00:00.000+09:002021-01-02T06:00:...          0
#
#               people_out station.name_full  geo.latitude  geo.longitude
# station_code
# 321                    0               충무로     37.561243     126.994280
# 2649                   0                신내     37.612668     127.103213
# 2615                   0               연신내     37.619001     126.921008

# %%
# 승차인원 top 3 역
top_in_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in top_in.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(top_in_map)
top_in_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a935049836b461e822f9eef78e41be26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a935049836b461e822f9eef78e41be26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a935049836b461e822f9eef78e41be26 = L.map(
#                 &quot;map_a935049836b461e822f9eef78e41be26&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b381d5e5c50c59d28ef91421bac149b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a935049836b461e822f9eef78e41be26);
#
#
#             var marker_9fe7277f3800284040d156ae2fa97d04 = L.marker(
#                 [37.51395, 127.102234],
#                 {}
#             ).addTo(map_a935049836b461e822f9eef78e41be26);
#
#
#             var icon_7509801e8738730d5335f0c28b0370fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9fe7277f3800284040d156ae2fa97d04.setIcon(icon_7509801e8738730d5335f0c28b0370fc);
#
#
#         var popup_02e171af92c2540624a9e2e87fd93d42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_949828e719de0ab5c12eb949e0e0cea9 = $(`&lt;div id=&quot;html_949828e719de0ab5c12eb949e0e0cea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;잠실(송파구청)&lt;/div&gt;`)[0];
#                 popup_02e171af92c2540624a9e2e87fd93d42.setContent(html_949828e719de0ab5c12eb949e0e0cea9);
#
#
#
#         marker_9fe7277f3800284040d156ae2fa97d04.bindPopup(popup_02e171af92c2540624a9e2e87fd93d42)
#         ;
#
#
#
#
#             var marker_51c1c864a82f845027f81aacd6eacc40 = L.marker(
#                 [37.484201, 126.929715],
#                 {}
#             ).addTo(map_a935049836b461e822f9eef78e41be26);
#
#
#             var icon_c26a61da4c856543730497d44fe1332d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51c1c864a82f845027f81aacd6eacc40.setIcon(icon_c26a61da4c856543730497d44fe1332d);
#
#
#         var popup_d58aa233214ab212c1f65f33898f5c96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb43ae3c080fec116a23864ee39915d7 = $(`&lt;div id=&quot;html_cb43ae3c080fec116a23864ee39915d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신림&lt;/div&gt;`)[0];
#                 popup_d58aa233214ab212c1f65f33898f5c96.setContent(html_cb43ae3c080fec116a23864ee39915d7);
#
#
#
#         marker_51c1c864a82f845027f81aacd6eacc40.bindPopup(popup_d58aa233214ab212c1f65f33898f5c96)
#         ;
#
#
#
#
#             var marker_fa4f64a6619f863bbbc7b79bc9710754 = L.marker(
#                 [37.497175, 127.027926],
#                 {}
#             ).addTo(map_a935049836b461e822f9eef78e41be26);
#
#
#             var icon_801eb94698eef3a71f17236e713b5f74 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa4f64a6619f863bbbc7b79bc9710754.setIcon(icon_801eb94698eef3a71f17236e713b5f74);
#
#
#         var popup_09e8a268fcee73705597299cda53dfa8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12ef5e49a3d3ec7358e9839287ba74ac = $(`&lt;div id=&quot;html_12ef5e49a3d3ec7358e9839287ba74ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남&lt;/div&gt;`)[0];
#                 popup_09e8a268fcee73705597299cda53dfa8.setContent(html_12ef5e49a3d3ec7358e9839287ba74ac);
#
#
#
#         marker_fa4f64a6619f863bbbc7b79bc9710754.bindPopup(popup_09e8a268fcee73705597299cda53dfa8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 승차 인원 하위 3개 역
low_in_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in low_in.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(low_in_map)
low_in_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c3729781e2f5e26cbe6072fa5ff8e31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c3729781e2f5e26cbe6072fa5ff8e31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c3729781e2f5e26cbe6072fa5ff8e31 = L.map(
#                 &quot;map_8c3729781e2f5e26cbe6072fa5ff8e31&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfd0ae9d2e931084fab8218df8c3aee7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c3729781e2f5e26cbe6072fa5ff8e31);
#
#
#             var marker_880911437cce9819506cd72d20d3d5b0 = L.marker(
#                 [37.619001, 126.921008],
#                 {}
#             ).addTo(map_8c3729781e2f5e26cbe6072fa5ff8e31);
#
#
#             var icon_19274b947592bb416ff24f977ca8e3f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_880911437cce9819506cd72d20d3d5b0.setIcon(icon_19274b947592bb416ff24f977ca8e3f4);
#
#
#         var popup_691671f9af9e366b93e709b4b69c0eb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8d6a11703f34252428a4070768bb275 = $(`&lt;div id=&quot;html_f8d6a11703f34252428a4070768bb275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연신내&lt;/div&gt;`)[0];
#                 popup_691671f9af9e366b93e709b4b69c0eb4.setContent(html_f8d6a11703f34252428a4070768bb275);
#
#
#
#         marker_880911437cce9819506cd72d20d3d5b0.bindPopup(popup_691671f9af9e366b93e709b4b69c0eb4)
#         ;
#
#
#
#
#             var marker_814192810a2ebdf0c52a23eb8f33177e = L.marker(
#                 [37.561243, 126.99428],
#                 {}
#             ).addTo(map_8c3729781e2f5e26cbe6072fa5ff8e31);
#
#
#             var icon_fece3fbfb196cf2eabade31d0c24fe22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_814192810a2ebdf0c52a23eb8f33177e.setIcon(icon_fece3fbfb196cf2eabade31d0c24fe22);
#
#
#         var popup_1317178e22d0ae5f2bf0237e117e6f48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7691b154c65306765db80c9e3add7a7d = $(`&lt;div id=&quot;html_7691b154c65306765db80c9e3add7a7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;충무로&lt;/div&gt;`)[0];
#                 popup_1317178e22d0ae5f2bf0237e117e6f48.setContent(html_7691b154c65306765db80c9e3add7a7d);
#
#
#
#         marker_814192810a2ebdf0c52a23eb8f33177e.bindPopup(popup_1317178e22d0ae5f2bf0237e117e6f48)
#         ;
#
#
#
#
#             var marker_b313f0c1171e67b9bf36845655faa4ea = L.marker(
#                 [37.612668, 127.103213],
#                 {}
#             ).addTo(map_8c3729781e2f5e26cbe6072fa5ff8e31);
#
#
#             var icon_0cd6c1ac2f7433abe3e03cf673f84f26 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b313f0c1171e67b9bf36845655faa4ea.setIcon(icon_0cd6c1ac2f7433abe3e03cf673f84f26);
#
#
#         var popup_a0c489323ee50275d8e942dfdcfe4f82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36a341d8018844c364aafebfec7cbd1a = $(`&lt;div id=&quot;html_36a341d8018844c364aafebfec7cbd1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신내&lt;/div&gt;`)[0];
#                 popup_a0c489323ee50275d8e942dfdcfe4f82.setContent(html_36a341d8018844c364aafebfec7cbd1a);
#
#
#
#         marker_b313f0c1171e67b9bf36845655faa4ea.bindPopup(popup_a0c489323ee50275d8e942dfdcfe4f82)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 하차 인원 top 3 역
top_out_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in top_out.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(top_out_map)
top_out_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26a23a37fe25b6568810caba6e777868 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26a23a37fe25b6568810caba6e777868&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26a23a37fe25b6568810caba6e777868 = L.map(
#                 &quot;map_26a23a37fe25b6568810caba6e777868&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b06a78e3f8fa1ef083e07c3bf8d16a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26a23a37fe25b6568810caba6e777868);
#
#
#             var marker_cbcfa2095b3dc614b5e98af36b9532db = L.marker(
#                 [37.51395, 127.102234],
#                 {}
#             ).addTo(map_26a23a37fe25b6568810caba6e777868);
#
#
#             var icon_51ceae67a51e71142774188642efb8bf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbcfa2095b3dc614b5e98af36b9532db.setIcon(icon_51ceae67a51e71142774188642efb8bf);
#
#
#         var popup_0eda094cc9532fe88d463fc2203302e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7beebab3975e10c4093c8be53b5f1b82 = $(`&lt;div id=&quot;html_7beebab3975e10c4093c8be53b5f1b82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;잠실(송파구청)&lt;/div&gt;`)[0];
#                 popup_0eda094cc9532fe88d463fc2203302e7.setContent(html_7beebab3975e10c4093c8be53b5f1b82);
#
#
#
#         marker_cbcfa2095b3dc614b5e98af36b9532db.bindPopup(popup_0eda094cc9532fe88d463fc2203302e7)
#         ;
#
#
#
#
#             var marker_5fcd9303f2383cefff1fe9db9b1ed4b3 = L.marker(
#                 [37.484201, 126.929715],
#                 {}
#             ).addTo(map_26a23a37fe25b6568810caba6e777868);
#
#
#             var icon_f5943853824033058b5f18d569389d58 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5fcd9303f2383cefff1fe9db9b1ed4b3.setIcon(icon_f5943853824033058b5f18d569389d58);
#
#
#         var popup_d7c922d45e44d15756d9292b4f574988 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f395ab3b84716eeb7487737d4c5cdae = $(`&lt;div id=&quot;html_7f395ab3b84716eeb7487737d4c5cdae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신림&lt;/div&gt;`)[0];
#                 popup_d7c922d45e44d15756d9292b4f574988.setContent(html_7f395ab3b84716eeb7487737d4c5cdae);
#
#
#
#         marker_5fcd9303f2383cefff1fe9db9b1ed4b3.bindPopup(popup_d7c922d45e44d15756d9292b4f574988)
#         ;
#
#
#
#
#             var marker_f60ee87655c4d556912ba914664fb8a3 = L.marker(
#                 [37.497175, 127.027926],
#                 {}
#             ).addTo(map_26a23a37fe25b6568810caba6e777868);
#
#
#             var icon_f79ab5e340e41a4558440eeedfc33251 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f60ee87655c4d556912ba914664fb8a3.setIcon(icon_f79ab5e340e41a4558440eeedfc33251);
#
#
#         var popup_583747be6413fc698c9c3b63100e9167 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be613b8d7a05f9333f39ec07df07011f = $(`&lt;div id=&quot;html_be613b8d7a05f9333f39ec07df07011f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남&lt;/div&gt;`)[0];
#                 popup_583747be6413fc698c9c3b63100e9167.setContent(html_be613b8d7a05f9333f39ec07df07011f);
#
#
#
#         marker_f60ee87655c4d556912ba914664fb8a3.bindPopup(popup_583747be6413fc698c9c3b63100e9167)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 하차 인원 하위 3개 역
low_out_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in low_out.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(low_out_map)
low_out_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c98470bf65136994de6efedbf32f1db1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c98470bf65136994de6efedbf32f1db1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c98470bf65136994de6efedbf32f1db1 = L.map(
#                 &quot;map_c98470bf65136994de6efedbf32f1db1&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a39e85006f3a654755b223c8177b87f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c98470bf65136994de6efedbf32f1db1);
#
#
#             var marker_1f3d3de7b11c6ceca4cb63c4fd8b24ed = L.marker(
#                 [37.561243, 126.99428],
#                 {}
#             ).addTo(map_c98470bf65136994de6efedbf32f1db1);
#
#
#             var icon_8501ac287309ad87abb36e45c7f70bb1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f3d3de7b11c6ceca4cb63c4fd8b24ed.setIcon(icon_8501ac287309ad87abb36e45c7f70bb1);
#
#
#         var popup_94cdef485f188dd285b5995dae30238c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_406bce05b86189b1389e1baf5ad1a1c1 = $(`&lt;div id=&quot;html_406bce05b86189b1389e1baf5ad1a1c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;충무로&lt;/div&gt;`)[0];
#                 popup_94cdef485f188dd285b5995dae30238c.setContent(html_406bce05b86189b1389e1baf5ad1a1c1);
#
#
#
#         marker_1f3d3de7b11c6ceca4cb63c4fd8b24ed.bindPopup(popup_94cdef485f188dd285b5995dae30238c)
#         ;
#
#
#
#
#             var marker_70ba852ec01840a09b833c83bfd0e936 = L.marker(
#                 [37.612668, 127.103213],
#                 {}
#             ).addTo(map_c98470bf65136994de6efedbf32f1db1);
#
#
#             var icon_e488d120ba6df47d75ce06c2be647c02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_70ba852ec01840a09b833c83bfd0e936.setIcon(icon_e488d120ba6df47d75ce06c2be647c02);
#
#
#         var popup_7b12699d70ad6ed40245d3611a836085 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2c56834c84be84026d8bd6472378f2f = $(`&lt;div id=&quot;html_a2c56834c84be84026d8bd6472378f2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신내&lt;/div&gt;`)[0];
#                 popup_7b12699d70ad6ed40245d3611a836085.setContent(html_a2c56834c84be84026d8bd6472378f2f);
#
#
#
#         marker_70ba852ec01840a09b833c83bfd0e936.bindPopup(popup_7b12699d70ad6ed40245d3611a836085)
#         ;
#
#
#
#
#             var marker_1d1afa825aa09410f4b1c27be9b0e348 = L.marker(
#                 [37.619001, 126.921008],
#                 {}
#             ).addTo(map_c98470bf65136994de6efedbf32f1db1);
#
#
#             var icon_58cf70d962195cb4b810879467f08383 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1d1afa825aa09410f4b1c27be9b0e348.setIcon(icon_58cf70d962195cb4b810879467f08383);
#
#
#         var popup_c2e4115fe9d0828989708af934068def = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd35561dcfb5cfad1c5d2aa644c81d11 = $(`&lt;div id=&quot;html_dd35561dcfb5cfad1c5d2aa644c81d11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연신내&lt;/div&gt;`)[0];
#                 popup_c2e4115fe9d0828989708af934068def.setContent(html_dd35561dcfb5cfad1c5d2aa644c81d11);
#
#
#
#         marker_1d1afa825aa09410f4b1c27be9b0e348.bindPopup(popup_c2e4115fe9d0828989708af934068def)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
