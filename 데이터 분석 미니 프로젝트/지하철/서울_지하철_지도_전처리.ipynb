# %% [markdown]
# <a href="https://colab.research.google.com/github/Seongjin1225/AI_SCHOOL_9/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EB%AF%B8%EB%8B%88%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/%EC%A7%80%ED%95%98%EC%B2%A0/%EC%84%9C%EC%9A%B8_%EC%A7%80%ED%95%98%EC%B2%A0_%EC%A7%80%EB%8F%84_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 문제 1. 불금 지하철 하차 히트맵 & 토요일 아침 복귀 인원 히트맵
# # 문제 2. 위와 동일 but 상위 3개 하위 3개 동그라미 처리(red,blue)

# %%
# 라이브러리 호출
import pandas as pd
import folium

# 데이터 불러오기 및 데이터 확인
data = pd.read_csv('/content/drive/MyDrive/AI스쿨 파일/데이터 분석/seoul-metro-2021.logs.csv')
info = pd.read_csv('/content/drive/MyDrive/AI스쿨 파일/데이터 분석/seoul-metro-station-info.csv')
data.head()
info.head()

# 필요한 컬럼만 추출하기
info = info[['station.code','geo.latitude','geo.longitude']]
info.head()

# 역 정보 기준으로 그룹화
data_sum = data.groupby('station_code').sum(numeric_only=False)  # 숫자형 데이터 타입 아닌거 있는 경우는 numeric_only=False 해줘야함
data_sum

# 데이터 합치기 위해 info의 인덱스 재설정
info = info.set_index('station.code')

# join 사용해 두 데이터 합치기
joined_data = data_sum.join(info)
joined_data.head()
# Out:
#                                                       timestamp  people_in  \
# station_code
# 150           2021-01-01T05:00:00.000+09:002021-01-01T06:00:...   12697273
# 151           2021-01-01T05:00:00.000+09:002021-01-01T06:00:...    5997344
# 152           2021-01-01T05:00:00.000+09:002021-01-01T06:00:...    9638952
# 153           2021-01-01T05:00:00.000+09:002021-01-01T06:00:...    7704599
# 154           2021-01-01T05:00:00.000+09:002021-01-01T06:00:...    6651283
#
#               people_out  geo.latitude  geo.longitude
# station_code
# 150             12109991     37.554648     126.972559
# 151              6030491     37.564718     126.977108
# 152              9284693     37.570161     126.982923
# 153              7090896     37.571607     126.991806
# 154              6609055     37.570926     127.001849

# %%
# 위에서 문제에 필요한 사전 작업은 다 마무리 했음
# 문제 1 풀기

# 불금 데이터 추출하기(19시~)
friday_data = data[(pd.to_datetime(data.timestamp).dt.weekday == 4) & (pd.to_datetime(data.timestamp).dt.hour > 18)]
friday_data.head()

# 토요일 오전 5~8시 데이터 추출
saturday_data = data[(pd.to_datetime(data.timestamp).dt.weekday==5) & (pd.to_datetime(data.timestamp).dt.hour < 9)]
saturday_data.head()

# 각각의 데이터 그룹화
friday_group = friday_data.groupby('station_code').sum(numeric_only=False)
friday_group.head()

saturday_group = saturday_data.groupby('station_code').sum(numeric_only=False)
saturday_group.head()

# 각각의 데이터 합치기
friday_join = friday_group.join(info)
friday_join.head()

saturday_join = saturday_group.join(info)
saturday_join.head()
# Out:
#                                                       timestamp  people_in  \
# station_code
# 150           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...      99950
# 151           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...      22421
# 152           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...      26109
# 153           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...      30886
# 154           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...      23193
#
#               people_out  geo.latitude  geo.longitude
# station_code
# 150               197738     37.554648     126.972559
# 151                79892     37.564718     126.977108
76037.0], [37.648627, 127.034709, 58763.0], [37.638052, 127.025732, 81897.0], [37.62667, 127.025983, 42730.0], [37.613292, 127.030053, 65527.0], [37.603407, 127.025053, 50006.0], [37.592624, 127.016403, 47149.0], [37.588458, 127.006221, 39826.0], [37.582336, 127.001844, 88184.0], [37.57142, 127.009745, 94543.0], [37.565138, 127.007896, 53684.0], [37.561243, 126.99428, 96146.0], [37.560989, 126.986325, 54822.0], [37.558514, 126.978246, 92638.0], [37.554648, 126.972559, 57895.0], [37.54456, 126.972106, 36348.0], [37.534777, 126.97311, 13898.

# %% [markdown]
# ## 문제 2번

# %%
# 라이브러리 호출
import pandas as pd
import folium

# 데이터 불러오기 및 데이터 확인
data = pd.read_csv('/content/drive/MyDrive/AI스쿨 파일/데이터 분석/seoul-metro-2021.logs.csv')
info = pd.read_csv('/content/drive/MyDrive/AI스쿨 파일/데이터 분석/seoul-metro-station-info.csv')
data.head()
info.head()

# 필요한 컬럼만 추출하기
info = info[['station.code', 'station.name_full', 'geo.latitude','geo.longitude']]
info.head()

# 역 정보 기준으로 그룹화
data_sum = data.groupby('station_code').sum(numeric_only=False)  # 숫자형 데이터 타입 아닌거 있는 경우는 numeric_only=False 해줘야함
data_sum

# 데이터 합치기 위해 info의 인덱스 재설정
info = info.set_index('station.code')

# join 사용해 두 데이터 합치기
joined_data = data_sum.join(info)
joined_data.head()

# 2021년 1월 데이터만 추출
data_jan = data[(pd.to_datetime(data.timestamp).dt.year == 2021) & (pd.to_datetime(data.timestamp).dt.month == 1)]
jan_group = data_jan.groupby('station_code').sum(numeric_only=False)
jan_join = jan_group.join(info)

# 승차 상하위 3개 데이터
top_in = jan_join.sort_values(by='people_in')[-3:]
top_in
low_in = jan_join.sort_values(by='people_in')[:3]
low_in

# 하차 상하위 3개 데이터
top_out = jan_join.sort_values(by='people_out')[-3:]
top_out[-3:]
low_out = jan_join.sort_values(by='people_out')[:3]
low_out
# Out:
#                                                       timestamp  people_in  \
# station_code
# 321           2021-01-02T05:00:00.000+09:002021-01-02T06:00:...          0
# 2649          2021-01-07T05:00:00.000+09:002021-01-07T06:00:...          0
# 2615          2021-01-02T05:00:00.000+09:002021-01-02T06:00:...          0
#
#               people_out station.name_full  geo.latitude  geo.longitude
# station_code
# 321                    0               충무로     37.561243     126.994280
# 2649                   0                신내     37.612668     127.103213
# 2615                   0               연신내     37.619001     126.921008

# %%
# 승차 top 3 역 지도에 표시
top_in_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in top_in.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(top_in_map)
top_in_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72b9d9a1370fcaaa0be33e23ffc7590e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72b9d9a1370fcaaa0be33e23ffc7590e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72b9d9a1370fcaaa0be33e23ffc7590e = L.map(
#                 &quot;map_72b9d9a1370fcaaa0be33e23ffc7590e&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bf2532a9e6b2c081992d2206272c2ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72b9d9a1370fcaaa0be33e23ffc7590e);
#
#
#             var marker_566f637f618dcf6e9c62ace95b02d611 = L.marker(
#                 [37.51395, 127.102234],
#                 {}
#             ).addTo(map_72b9d9a1370fcaaa0be33e23ffc7590e);
#
#
#             var icon_5bda1828d560086c07bd48013fbe5192 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_566f637f618dcf6e9c62ace95b02d611.setIcon(icon_5bda1828d560086c07bd48013fbe5192);
#
#
#         var popup_e349b4909115c589353f7270e8513590 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40f1c36fac3f56b5154aadd3eb06dac6 = $(`&lt;div id=&quot;html_40f1c36fac3f56b5154aadd3eb06dac6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;잠실(송파구청)&lt;/div&gt;`)[0];
#                 popup_e349b4909115c589353f7270e8513590.setContent(html_40f1c36fac3f56b5154aadd3eb06dac6);
#
#
#
#         marker_566f637f618dcf6e9c62ace95b02d611.bindPopup(popup_e349b4909115c589353f7270e8513590)
#         ;
#
#
#
#
#             var marker_4c59c7d7b7afbcde4b55ac7de13a8dc6 = L.marker(
#                 [37.484201, 126.929715],
#                 {}
#             ).addTo(map_72b9d9a1370fcaaa0be33e23ffc7590e);
#
#
#             var icon_54057ffcbc72b2bd19b2c14d250d72dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c59c7d7b7afbcde4b55ac7de13a8dc6.setIcon(icon_54057ffcbc72b2bd19b2c14d250d72dc);
#
#
#         var popup_48cdf99390147bebfe69cbc4353bcc5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d006f24242640d2b13bb8ed9a9773ec = $(`&lt;div id=&quot;html_1d006f24242640d2b13bb8ed9a9773ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신림&lt;/div&gt;`)[0];
#                 popup_48cdf99390147bebfe69cbc4353bcc5e.setContent(html_1d006f24242640d2b13bb8ed9a9773ec);
#
#
#
#         marker_4c59c7d7b7afbcde4b55ac7de13a8dc6.bindPopup(popup_48cdf99390147bebfe69cbc4353bcc5e)
#         ;
#
#
#
#
#             var marker_f21553476f47b5aa0d9633f289f04197 = L.marker(
#                 [37.497175, 127.027926],
#                 {}
#             ).addTo(map_72b9d9a1370fcaaa0be33e23ffc7590e);
#
#
#             var icon_fd7c7c336444e6392fad2df95ffbff5d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f21553476f47b5aa0d9633f289f04197.setIcon(icon_fd7c7c336444e6392fad2df95ffbff5d);
#
#
#         var popup_52b0e4922ef5577a115df2cbea228500 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c6f16d5ac246fcbccbea9a1bf1c7412 = $(`&lt;div id=&quot;html_1c6f16d5ac246fcbccbea9a1bf1c7412&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남&lt;/div&gt;`)[0];
#                 popup_52b0e4922ef5577a115df2cbea228500.setContent(html_1c6f16d5ac246fcbccbea9a1bf1c7412);
#
#
#
#         marker_f21553476f47b5aa0d9633f289f04197.bindPopup(popup_52b0e4922ef5577a115df2cbea228500)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
low_in_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in low_in.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(low_in_map)
low_in_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b9a3e9cdf097d83afec6abb82a94591 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b9a3e9cdf097d83afec6abb82a94591&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b9a3e9cdf097d83afec6abb82a94591 = L.map(
#                 &quot;map_0b9a3e9cdf097d83afec6abb82a94591&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffe9529548c8a105cbe03f94a6e49267 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b9a3e9cdf097d83afec6abb82a94591);
#
#
#             var marker_62ad2e3bccc3e3b5a1b33bff9e366490 = L.marker(
#                 [37.619001, 126.921008],
#                 {}
#             ).addTo(map_0b9a3e9cdf097d83afec6abb82a94591);
#
#
#             var icon_1da2a5e7fcd3d36a13dc9873a631c0ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_62ad2e3bccc3e3b5a1b33bff9e366490.setIcon(icon_1da2a5e7fcd3d36a13dc9873a631c0ec);
#
#
#         var popup_69b61617c9f57066e0a0b495dcba5a85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73966362b2b9ab49be33e7d1374f1faa = $(`&lt;div id=&quot;html_73966362b2b9ab49be33e7d1374f1faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연신내&lt;/div&gt;`)[0];
#                 popup_69b61617c9f57066e0a0b495dcba5a85.setContent(html_73966362b2b9ab49be33e7d1374f1faa);
#
#
#
#         marker_62ad2e3bccc3e3b5a1b33bff9e366490.bindPopup(popup_69b61617c9f57066e0a0b495dcba5a85)
#         ;
#
#
#
#
#             var marker_dc595f81e6d539a95a6a7f21aca74e13 = L.marker(
#                 [37.561243, 126.99428],
#                 {}
#             ).addTo(map_0b9a3e9cdf097d83afec6abb82a94591);
#
#
#             var icon_8a0bb75f3b2fecdcbd739eb02645d04c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc595f81e6d539a95a6a7f21aca74e13.setIcon(icon_8a0bb75f3b2fecdcbd739eb02645d04c);
#
#
#         var popup_c24892d93ff6c54a514a631d3de0976b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a17a600ac0292b9f80d3c0e3a50f4e62 = $(`&lt;div id=&quot;html_a17a600ac0292b9f80d3c0e3a50f4e62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;충무로&lt;/div&gt;`)[0];
#                 popup_c24892d93ff6c54a514a631d3de0976b.setContent(html_a17a600ac0292b9f80d3c0e3a50f4e62);
#
#
#
#         marker_dc595f81e6d539a95a6a7f21aca74e13.bindPopup(popup_c24892d93ff6c54a514a631d3de0976b)
#         ;
#
#
#
#
#             var marker_7d9d68fa84dae39fd98b2ad841ed6708 = L.marker(
#                 [37.612668, 127.103213],
#                 {}
#             ).addTo(map_0b9a3e9cdf097d83afec6abb82a94591);
#
#
#             var icon_cd3916af6f58f79a46865daa7283ad94 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d9d68fa84dae39fd98b2ad841ed6708.setIcon(icon_cd3916af6f58f79a46865daa7283ad94);
#
#
#         var popup_145e963c48bd183858bc1d8db1c7fc21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c80fc7f379385addeaab4e3ba7e404e = $(`&lt;div id=&quot;html_0c80fc7f379385addeaab4e3ba7e404e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신내&lt;/div&gt;`)[0];
#                 popup_145e963c48bd183858bc1d8db1c7fc21.setContent(html_0c80fc7f379385addeaab4e3ba7e404e);
#
#
#
#         marker_7d9d68fa84dae39fd98b2ad841ed6708.bindPopup(popup_145e963c48bd183858bc1d8db1c7fc21)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 하차 top 3 역 지도에 표시
top_out_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in top_out.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(top_out_map)
top_out_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab7b132c643f2d23dbb1863447f9e4b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab7b132c643f2d23dbb1863447f9e4b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab7b132c643f2d23dbb1863447f9e4b6 = L.map(
#                 &quot;map_ab7b132c643f2d23dbb1863447f9e4b6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e3e89def9cdea365005c1817cfc5983 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab7b132c643f2d23dbb1863447f9e4b6);
#
#
#             var marker_9cfb0bf289a50c7f9e1419999f87ce00 = L.marker(
#                 [37.51395, 127.102234],
#                 {}
#             ).addTo(map_ab7b132c643f2d23dbb1863447f9e4b6);
#
#
#             var icon_517745e8cd6570158e3ef4dc0982f877 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9cfb0bf289a50c7f9e1419999f87ce00.setIcon(icon_517745e8cd6570158e3ef4dc0982f877);
#
#
#         var popup_c0258d136d6becc96112af345914f0bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39783297d03439c5fbdaf76257ed7764 = $(`&lt;div id=&quot;html_39783297d03439c5fbdaf76257ed7764&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;잠실(송파구청)&lt;/div&gt;`)[0];
#                 popup_c0258d136d6becc96112af345914f0bc.setContent(html_39783297d03439c5fbdaf76257ed7764);
#
#
#
#         marker_9cfb0bf289a50c7f9e1419999f87ce00.bindPopup(popup_c0258d136d6becc96112af345914f0bc)
#         ;
#
#
#
#
#             var marker_78b75dfcca9a33dcee51b06894f6630d = L.marker(
#                 [37.484201, 126.929715],
#                 {}
#             ).addTo(map_ab7b132c643f2d23dbb1863447f9e4b6);
#
#
#             var icon_e2cdea5b4585b507d208c4c7d4361945 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_78b75dfcca9a33dcee51b06894f6630d.setIcon(icon_e2cdea5b4585b507d208c4c7d4361945);
#
#
#         var popup_05750191bfbb01b52ddd4c691840abc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e44a52c46eedb98c41a500d5faa446de = $(`&lt;div id=&quot;html_e44a52c46eedb98c41a500d5faa446de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신림&lt;/div&gt;`)[0];
#                 popup_05750191bfbb01b52ddd4c691840abc2.setContent(html_e44a52c46eedb98c41a500d5faa446de);
#
#
#
#         marker_78b75dfcca9a33dcee51b06894f6630d.bindPopup(popup_05750191bfbb01b52ddd4c691840abc2)
#         ;
#
#
#
#
#             var marker_05677e9202ac6a26942d25abf699e092 = L.marker(
#                 [37.497175, 127.027926],
#                 {}
#             ).addTo(map_ab7b132c643f2d23dbb1863447f9e4b6);
#
#
#             var icon_4a26aea318e49e1a86618ce3d434c35d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_05677e9202ac6a26942d25abf699e092.setIcon(icon_4a26aea318e49e1a86618ce3d434c35d);
#
#
#         var popup_a6140b1d4480a5dcee528b2a528ab7d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0d355e372754460861d5911d41019ce = $(`&lt;div id=&quot;html_b0d355e372754460861d5911d41019ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남&lt;/div&gt;`)[0];
#                 popup_a6140b1d4480a5dcee528b2a528ab7d8.setContent(html_b0d355e372754460861d5911d41019ce);
#
#
#
#         marker_05677e9202ac6a26942d25abf699e092.bindPopup(popup_a6140b1d4480a5dcee528b2a528ab7d8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
low_out_map = folium.Map(location=[37.55, 126.98], zoom_start = 12)

for idx, row in low_out.iterrows():
    folium.Marker(location=[row['geo.latitude'], row['geo.longitude']], popup=row['station.name_full'],
                  icon=folium.Icon(color='blue',icon='star')).add_to(low_out_map)
low_out_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c08fef478acc48fa2d9ef916b85a6466 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c08fef478acc48fa2d9ef916b85a6466&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c08fef478acc48fa2d9ef916b85a6466 = L.map(
#                 &quot;map_c08fef478acc48fa2d9ef916b85a6466&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deec419ecfe0fd1ddadab92be3e3eb42 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c08fef478acc48fa2d9ef916b85a6466);
#
#
#             var marker_3cf22991945b6cdd02826a66966be40e = L.marker(
#                 [37.561243, 126.99428],
#                 {}
#             ).addTo(map_c08fef478acc48fa2d9ef916b85a6466);
#
#
#             var icon_e2cbc3fab553d625204e26c2227f18a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3cf22991945b6cdd02826a66966be40e.setIcon(icon_e2cbc3fab553d625204e26c2227f18a7);
#
#
#         var popup_95c27b61329cd1d3343e9ba1e608135f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24a3f0de1249ce7fd3f662786c1a3f5a = $(`&lt;div id=&quot;html_24a3f0de1249ce7fd3f662786c1a3f5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;충무로&lt;/div&gt;`)[0];
#                 popup_95c27b61329cd1d3343e9ba1e608135f.setContent(html_24a3f0de1249ce7fd3f662786c1a3f5a);
#
#
#
#         marker_3cf22991945b6cdd02826a66966be40e.bindPopup(popup_95c27b61329cd1d3343e9ba1e608135f)
#         ;
#
#
#
#
#             var marker_1326068fd462901d6409a5c334b2efa5 = L.marker(
#                 [37.612668, 127.103213],
#                 {}
#             ).addTo(map_c08fef478acc48fa2d9ef916b85a6466);
#
#
#             var icon_1576fc04d9959d66bcfef557cd128a00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1326068fd462901d6409a5c334b2efa5.setIcon(icon_1576fc04d9959d66bcfef557cd128a00);
#
#
#         var popup_7e7bdbf7b477fd12120f28b2514d171c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c384dc46833a16b3a8f9c1b25bdf6da3 = $(`&lt;div id=&quot;html_c384dc46833a16b3a8f9c1b25bdf6da3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신내&lt;/div&gt;`)[0];
#                 popup_7e7bdbf7b477fd12120f28b2514d171c.setContent(html_c384dc46833a16b3a8f9c1b25bdf6da3);
#
#
#
#         marker_1326068fd462901d6409a5c334b2efa5.bindPopup(popup_7e7bdbf7b477fd12120f28b2514d171c)
#         ;
#
#
#
#
#             var marker_bb54cb0450cc4a1f27c90c4d3cbc9ffa = L.marker(
#                 [37.619001, 126.921008],
#                 {}
#             ).addTo(map_c08fef478acc48fa2d9ef916b85a6466);
#
#
#             var icon_9feca27b71c20eb4af9f2942235a6be7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bb54cb0450cc4a1f27c90c4d3cbc9ffa.setIcon(icon_9feca27b71c20eb4af9f2942235a6be7);
#
#
#         var popup_4746e2b869cdf8cc4245fcf0e687cd7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99382befd9d206c988b797872236482d = $(`&lt;div id=&quot;html_99382befd9d206c988b797872236482d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연신내&lt;/div&gt;`)[0];
#                 popup_4746e2b869cdf8cc4245fcf0e687cd7d.setContent(html_99382befd9d206c988b797872236482d);
#
#
#
#         marker_bb54cb0450cc4a1f27c90c4d3cbc9ffa.bindPopup(popup_4746e2b869cdf8cc4245fcf0e687cd7d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
